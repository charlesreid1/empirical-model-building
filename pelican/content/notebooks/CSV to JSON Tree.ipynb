# %% [markdown]
# The purpose of this notebook is to convert flat CSV data into hierarchical categorical data in JSON format. This is then passed to D3 to construct a sunburst chart. While we could do this slicing-and-dicing with D3 or other Javascript libraries, this provides a far more flexible implementation. By using Python to deal with complicated logic, Javascript chart code is kept uncluttered with data transformations.
#
# We begin by importing Pandas, which we'll use to store the flat budget data. The defaultdict type provides a convenient data storage container, and the json library is used at the end when we dump out the processed hierarchical JSON to a JSON file.

# %%
import pandas as pd
from collections import defaultdict
import json

# %% [markdown]
# We start by defning a function to turn the flat dataframe data into a hierarchical JSON structure. This function will be called once for each year of budget data that we have. One call corresponds to one budget year corresponds to one sunburst chart.

# %%
def treeify_dataframe(df,groupby_groups,value_label):

    # Turn this flat dataframe into hierarchial, nested JSON
    #
    # groupby_groups:
    # variable labels that encode hierarchial information for the radian rings
    # Example: 'Fund name', 'Department', 'BCL Name'
    # 
    # value_label: 
    # values that are associated with keys, used for display stuff.
    # Example: 'Description', '2012 Amount'


    def rec_dd():
        return defaultdict(rec_dd)

    # First, create a recursive default dictionary
    # Populate it with our hierarchical structure
    tree = rec_dd()

    # the recursive default dictionary allows you to say something like,
    # my_rec_dd['a']['b']['c']['d']
    #
    # and when you print my_rec_dd, it will show as:
    # {'a': {'b': {'c': {'d': {}} } } }
    # 
    # This is a stepping stone to turning flat categorical data
    # into a nested hierarchy
    
    
    ###################
    # Group by groupby groups
    #
    bcl_groupby = df.groupby(groupby_groups)
    bcl_groups = bcl_groupby.groups
    

    
    ###################
    # JSON Tree Structure

    tree = rec_dd()
    
    # Populate the JSON skeleton
    
    for k,v in zip(bcl_groups.keys(),bcl_groups.values()):
        dfvalue = df.ix[v][value_label].values[0]
        
        if type(dfvalue)==type('asdf'):
            
            # in 2012 budget data, dollar values were strings, '$10000'
            tree[k[0]][k[1]][k[2]] = float(df.ix[v][value_label].values[0][1:])
        
        else:
            
            # in 2013/2014 budget data, dollar values were numbers, 10000
            tree[k[0]][k[1]][k[2]] = dfvalue

    
    
    ###################
    # D3 Tree Structure
    #
    # this looks like this:
    # 
    # { 'name' : 'node1',
    #   'children' : [ 
    #                  { 'name' : 'node2', 
    #   ...
    
    def treeify(node,curIndex):
        if curIndex==2:
            children = []
            for (k,v) in node.iteritems():
                child = {}
                child['name'] = k
                child['total'] = v
                children.append(child)
            return children
        else:
            children = []
            for k in node.keys():
                child = {}
                child['name'] = k
                child['children'] = treeify(node[k],curIndex+1)
                children.append(child)
            return children
    
    myjson = {}
    myjson['name'] = 'root'
    myjson['children'] = treeify(tree,0)
    
    return myjson

# %% [markdown]
# Now we call the function, once for each year. Start with 2012, then 2013, then 2014:

# %%
# Load 2012 budget data
df = pd.read_csv('budget2012.csv')

# these groupby groups form the rings of the sunburst chart
groupby_groups = ['Fund Name','Department','Budget Control Level (BCL) Name']

# this is the name of the dollar amount field
value_label ='2012 Expenditure Allowance'

# create treeified JSON structure
tree_json = treeify_dataframe(df,groupby_groups,value_label)

# and dump it to a JSON file
with open('budget2012.json','w') as f:
    json.dump(tree_json,f)

# %% [markdown]
# And just so we can see what the final JSON looks like:

# %%
print json.dumps(tree_json, separators=(',',': '), indent=4, sort_keys=False)
# Out:
# {
#     "name": "root",
#     "children": [
#         {
#             "name": "Special Employment Program Subfund (00515)",
#             "children": [
#                 {
#                     "name": "Personnel Department",
#                     "children": [
#                         {
#                             "total": 200000.0,
#                             "name": "Special Employment"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Firefighters Pension Fund (60200)",
#             "children": [
#                 {
#                     "name": "Firefighters' Pension",
#                     "children": [
#                         {
#                             "total": 19829267.0,
#                             "name": "Firefighters' Pension"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Streetcar Fund (10810)",
#             "children": [
#                 {
#                     "name": "Seattle Department of Transportation",
#                     "children": [
#                         {
#                             "total": 5736749.0,
#                             "name": "Streetcar Operations"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Neighborhood Matching Subfund (00165)",
#             "children": [
#                 {
#                     "name": "Department of Neighborhoods",
#                     "children": [
#                         {
#                             "total": 3292698.0,
#                             "name": "Neighborhood Matching Fund"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Human Services Operating Fund (16200)",
#             "children": [
#                 {
#                     "name": "Human Services Department",
#                     "children": [
#                         {
#                             "total": 13608754.0,
#                             "name": "Public Health Services"
#                         },
#                         {
#                             "total": 21021969.0,
#                             "name": "Youth and Family Empowerment"
#                         },
#                         {
#                             "total": 9232199.0,
#                             "name": "Leadership and Administration"
#                         },
#                         {
#                             "total": 30380335.0,
#                             "name": "Transitional Living and Support"
#                         },
#                         {
#                             "total": 36333735.0,
#                             "name": "Aging and Disability Services - Area Agency on Aging"
#                         },
#                         {
#                             "total": 11105623.0,
#                             "name": "Community Support and Self Sufficiency"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Water Fund",
#             "children": [
#                 {
#                     "name": "Seattle Public Utilities",
#                     "children": [
#                         {
#                             "total": 10903062.0,
#                             "name": "Administration"
#                         },
#                         {
#                             "total": 3075786.0,
#                             "name": "Transmission"
#                         },
#                         {
#                             "total": 10368549.0,
#                             "name": "Customer Service"
#                         },
#                         {
#                             "total": 143332578.0,
#                             "name": "General Expense"
#                         },
#                         {
#                             "total": 19402731.0,
#                             "name": "Shared Cost Projects"
#                         },
#                         {
#                             "total": 48921572.0,
#                             "name": "Other Operating"
#                         },
#                         {
#                             "total": 8212072.0,
#                             "name": "Water Resources"
#                         },
#                         {
#                             "total": 8596072.0,
#                             "name": "Technology"
#                         },
#                         {
#                             "total": 5303791.0,
#                             "name": "Water Quality & Treatment"
#                         },
#                         {
#                             "total": 1999.0,
#                             "name": "Watershed Stewardship"
#                         },
#                         {
#                             "total": 20393599.0,
#                             "name": "Distribution"
#                         },
#                         {
#                             "total": 2490751.0,
#                             "name": "Habitat Conservation Program"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Federal Vice Enforcement Forfeiture Fund (62480)",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 1850000.0,
#                             "name": "Public Safety Facilities - Police (62480-CIP)"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "2013 Multipurpose LTGO Bond Fund",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 1000000.0,
#                             "name": "Information Technology (35700-CIP)"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Judgment/ Claims Subfund (00126)",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 3862500.0,
#                             "name": "Claim Expenses"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Law Department",
#                     "children": [
#                         {
#                             "total": 1307208.0,
#                             "name": "Police Action Expenses"
#                         },
#                         {
#                             "total": 11586470.0,
#                             "name": "Litigation Expenses"
#                         },
#                         {
#                             "total": 103000.0,
#                             "name": "General Legal Expenses"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Parking Garage Operations Fund (46010)",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 8687760.0,
#                             "name": "Pacific Place Garage"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "2007 Multipurpose LTGO Bond Fund",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 2403303.0,
#                             "name": "Debt Issuance Costs"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Pike Place Levy (11010)",
#             "children": [
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 8951750.0,
#                             "name": "Pike Place Market Renovation Debt Service"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Low-Income Housing Fund (16400)",
#             "children": [
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 43092788.0,
#                             "name": "Low-Income Housing Fund 16400"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Information Technology Fund (50410)",
#             "children": [
#                 {
#                     "name": "Department of Information Technology",
#                     "children": [
#                         {
#                             "total": 38616236.0,
#                             "name": "Technology Infrastructure"
#                         },
#                         {
#                             "total": 39097911.0,
#                             "name": "Finance and Administration"
#                         },
#                         {
#                             "total": 2066185.0,
#                             "name": "Technology Leadership and Governance"
#                         },
#                         {
#                             "total": 7487300.0,
#                             "name": "Office of Electronic Communications"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Park and Recreation Fund (10200)",
#             "children": [
#                 {
#                     "name": "Department of Parks and Recreation",
#                     "children": [
#                         {
#                             "total": 15200447.0,
#                             "name": "Facility and Structure Maintenance"
#                         },
#                         {
#                             "total": 652212.0,
#                             "name": "Judgment and Claims"
#                         },
#                         {
#                             "total": 6193818.0,
#                             "name": "Planning, Development, and Acquisition"
#                         },
#                         {
#                             "total": 11173584.0,
#                             "name": "Golf"
#                         },
#                         {
#                             "total": 30537538.0,
#                             "name": "Park Cleaning, Landscaping, and Restoration"
#                         },
#                         {
#                             "total": 1648180.0,
#                             "name": "Environmental Learning and Programs"
#                         },
#                         {
#                             "total": 3460177.0,
#                             "name": "Seattle Aquarium"
#                         },
#                         {
#                             "total": 4051179.0,
#                             "name": "Seattle Conservation Corps"
#                         },
#                         {
#                             "total": 23290127.0,
#                             "name": "Recreation Facilities and Programs"
#                         },
#                         {
#                             "total": 8247208.0,
#                             "name": "Finance and Administration"
#                         },
#                         {
#                             "total": 6944151.0,
#                             "name": "Policy Direction and Leadership"
#                         },
#                         {
#                             "total": 6820029.0,
#                             "name": "Woodland Park Zoo"
#                         },
#                         {
#                             "total": 7170301.0,
#                             "name": "Natural Resources Management"
#                         },
#                         {
#                             "total": 9448624.0,
#                             "name": "Swimming, Boating, and Aquatics"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Industrial Insurance Subfund (00516)",
#             "children": [
#                 {
#                     "name": "Personnel Department",
#                     "children": [
#                         {
#                             "total": 19171000.0,
#                             "name": "Industrial Insurance"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "2008 Parks Levy Fund",
#             "children": [
#                 {
#                     "name": "Department of Parks and Recreation",
#                     "children": [
#                         {
#                             "total": 300000.0,
#                             "name": "2008 Parks Levy- Neighborhood Park Acquisition (33860- CIP)"
#                         },
#                         {
#                             "total": 75000.0,
#                             "name": "2008 Parks Levy- Shoreline Access (33860-CIP)"
#                         },
#                         {
#                             "total": 95000.0,
#                             "name": "2008 Parks Levy- Green Space Acquisition (33860- CIP)"
#                         },
#                         {
#                             "total": 426000.0,
#                             "name": "2008 Parks Levy- Forest & Stream Restoration (33860- CIP)"
#                         },
#                         {
#                             "total": 5700000.0,
#                             "name": "2008 Parks Levy- Neighborhood Parks and Playgrounds (33860- CIP)"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Police Relief and Pension Fund (60400)",
#             "children": [
#                 {
#                     "name": "Police Relief and Pension",
#                     "children": [
#                         {
#                             "total": 19359068.0,
#                             "name": "Police Relief and Pension"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Planning and Development Fund (15700)",
#             "children": [
#                 {
#                     "name": "Department of Planning and Development",
#                     "children": [
#                         {
#                             "total": 19928691.0,
#                             "name": "Construction Permit Services"
#                         },
#                         {
#                             "total": 4849027.0,
#                             "name": "Code Compliance"
#                         },
#                         {
#                             "total": 4159482.0,
#                             "name": "Annual Certification and Inspection"
#                         },
#                         {
#                             "total": 14547159.0,
#                             "name": "Construction Inspections"
#                         },
#                         {
#                             "total": 4851923.0,
#                             "name": "Land Use Services"
#                         },
#                         {
#                             "total": 6416007.0,
#                             "name": "Planning"
#                         },
#                         {
#                             "total": 2095009.0,
#                             "name": "Process Improvements and Technology"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Unemployment Insurance Subfunds (00517)",
#             "children": [
#                 {
#                     "name": "Personnel Department",
#                     "children": [
#                         {
#                             "total": 1001269.0,
#                             "name": "Unemployment Insurance"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Drainage and Wastewater Fund",
#             "children": [
#                 {
#                     "name": "Seattle Public Utilities",
#                     "children": [
#                         {
#                             "total": 2050342.0,
#                             "name": "Sediments"
#                         },
#                         {
#                             "total": 6248372.0,
#                             "name": "Administration"
#                         },
#                         {
#                             "total": 49201662.0,
#                             "name": "Combined Sewer Overflows"
#                         },
#                         {
#                             "total": 240054742.0,
#                             "name": "General Expense"
#                         },
#                         {
#                             "total": 11394835.0,
#                             "name": "Shared Cost Projects"
#                         },
#                         {
#                             "total": 5141941.0,
#                             "name": "Protection of Beneficial Uses"
#                         },
#                         {
#                             "total": 17201000.0,
#                             "name": "Flooding, Sewer Back-up, and Landslides"
#                         },
#                         {
#                             "total": 7612800.0,
#                             "name": "Technology"
#                         },
#                         {
#                             "total": 7506712.0,
#                             "name": "Customer Service"
#                         },
#                         {
#                             "total": 54825424.0,
#                             "name": "Other Operating"
#                         },
#                         {
#                             "total": 8770000.0,
#                             "name": "Rehabilitation"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "2011 Families and Education Levy (17857)",
#             "children": [
#                 {
#                     "name": "Department of Neighborhoods",
#                     "children": [
#                         {
#                             "total": 5656949.0,
#                             "name": "Middle School Academic Achievement and College/ Career Preparation"
#                         },
#                         {
#                             "total": 5759322.0,
#                             "name": "Elementary School Academic Achievement"
#                         },
#                         {
#                             "total": 2605102.0,
#                             "name": "High School Academic Achievement and College/ Career Preparation"
#                         },
#                         {
#                             "total": 1482823.0,
#                             "name": "Administration and Evaluation"
#                         },
#                         {
#                             "total": 6187471.0,
#                             "name": "Student Health"
#                         },
#                         {
#                             "total": 7249027.0,
#                             "name": "Early Learning and School Readiness"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Central Waterfront Improvement Fund",
#             "children": [
#                 {
#                     "name": "Seattle Department of Transportation",
#                     "children": [
#                         {
#                             "total": 595000.0,
#                             "name": "Central Waterfront Improvement Fund Interest Expense"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Cumulative Reserve Subfund, Asset Preservation Subaccount - Fleets and Facilities (00168)",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 800000.0,
#                             "name": "Asset Preservation - Civic Core (00168-CIP)"
#                         },
#                         {
#                             "total": 800000.0,
#                             "name": "Asset Preservation - Shops and Yards (00168-CIP)"
#                         },
#                         {
#                             "total": 1800000.0,
#                             "name": "Asset Preservation - Seattle Municipal Tower (00168- CIP)"
#                         },
#                         {
#                             "total": 400000.0,
#                             "name": "Asset Preservation - Public Safety Facilities (00168- CIP)"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Seattle Center Fund (11410)",
#             "children": [
#                 {
#                     "name": "Seattle Center",
#                     "children": [
#                         {
#                             "total": 2078338.0,
#                             "name": "Community Programs"
#                         },
#                         {
#                             "total": 702856.0,
#                             "name": "Judgment and Claims"
#                         },
#                         {
#                             "total": 6613284.0,
#                             "name": "KeyArena"
#                         },
#                         {
#                             "total": 7170262.0,
#                             "name": "Administration-SC"
#                         },
#                         {
#                             "total": 229145.0,
#                             "name": "Cultural Facilities"
#                         },
#                         {
#                             "total": 946293.0,
#                             "name": "Commercial Events"
#                         },
#                         {
#                             "total": 1249106.0,
#                             "name": "Access"
#                         },
#                         {
#                             "total": 12045194.0,
#                             "name": "Campus Grounds"
#                         },
#                         {
#                             "total": 1505509.0,
#                             "name": "Festivals"
#                         },
#                         {
#                             "total": 126450.0,
#                             "name": "Debt"
#                         },
#                         {
#                             "total": 4207416.0,
#                             "name": "McCaw Hall"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Library Fund (10410)",
#             "children": [
#                 {
#                     "name": "The Seattle Public Library",
#                     "children": [
#                         {
#                             "total": 1110902.0,
#                             "name": "Human Resources"
#                         },
#                         {
#                             "total": 1039300.0,
#                             "name": "City Librarian's Office"
#                         },
#                         {
#                             "total": 46806382.0,
#                             "name": "Library Services"
#                         },
#                         {
#                             "total": 11404244.0,
#                             "name": "Administrative Services"
#                         },
#                         {
#                             "total": 4907954.0,
#                             "name": "Information Technology"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Cumulative Reserve Subfund - REET I Subaccount (00163)",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 141000.0,
#                             "name": "General Government Facilities - General (00163-CIP)"
#                         },
#                         {
#                             "total": 1880000.0,
#                             "name": "Neighborhood Fire Stations (00163-CIP)"
#                         },
#                         {
#                             "total": 365000.0,
#                             "name": "Public Safety Facilities - Police (00163-CIP)"
#                         },
#                         {
#                             "total": 2552000.0,
#                             "name": "Maintenance Shops and Yards (00163-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Department of Planning and Development",
#                     "children": [
#                         {
#                             "total": 157436.0,
#                             "name": "Tenant Relocation Assistance Program REET I"
#                         },
#                         {
#                             "total": 508071.0,
#                             "name": "Design Commission - CRS REET I"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "The Seattle Public Library",
#                     "children": [
#                         {
#                             "total": 500000.0,
#                             "name": "Library Major Maintenance (00163-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 187000.0,
#                             "name": "Artwork Conservation - OACA - CRS REET I"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Department of Parks and Recreation",
#                     "children": [
#                         {
#                             "total": 514000.0,
#                             "name": "Ballfields/ Athletic Courts/ Play Areas (00163-CIP)"
#                         },
#                         {
#                             "total": 4068000.0,
#                             "name": "Building Component Renovations (00163-CIP)"
#                         },
#                         {
#                             "total": 1293000.0,
#                             "name": "Forest Restoration (00163-CIP)"
#                         },
#                         {
#                             "total": 803000.0,
#                             "name": "Debt Service and Contract Obligation (00163-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Center",
#                     "children": [
#                         {
#                             "total": 50000.0,
#                             "name": "Fisher Pavilion (00163-CIP)"
#                         },
#                         {
#                             "total": 300000.0,
#                             "name": "Public Gathering Space Improvements (00163-CIP)"
#                         },
#                         {
#                             "total": 275000.0,
#                             "name": "Utility Infrastructure (00163-CIP)"
#                         },
#                         {
#                             "total": 200000.0,
#                             "name": "Key Arena (00163-CIP)"
#                         },
#                         {
#                             "total": 1145000.0,
#                             "name": "Campuswide Improvements and Repairs (00163-CIP)"
#                         },
#                         {
#                             "total": 1044000.0,
#                             "name": "Center House Rehabilitation (00163-CIP)"
#                         },
#                         {
#                             "total": 200000.0,
#                             "name": "Facility Infrastructure Renovation and Repair (00163- CIP)"
#                         },
#                         {
#                             "total": 250000.0,
#                             "name": "CRS REET I Support to McCaw Hall Fund"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Department of Transportation",
#                     "children": [
#                         {
#                             "total": 1500000.0,
#                             "name": "CRS REET I Support to Transportation"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "City Light Fund",
#             "children": [
#                 {
#                     "name": "Seattle City Light",
#                     "children": [
#                         {
#                             "total": 61573633.0,
#                             "name": "Conservation Resources and Environmental Affairs O&M"
#                         },
#                         {
#                             "total": 73941794.0,
#                             "name": "Distribution Services"
#                         },
#                         {
#                             "total": 36575868.0,
#                             "name": "Financial Services - O&M"
#                         },
#                         {
#                             "total": 83447858.0,
#                             "name": "Transmission and Distribution - CIP"
#                         },
#                         {
#                             "total": 28307173.0,
#                             "name": "Customer Services"
#                         },
#                         {
#                             "total": 9137512.0,
#                             "name": "Human Resources"
#                         },
#                         {
#                             "total": 3442861.0,
#                             "name": "Compliance and Security"
#                         },
#                         {
#                             "total": 86159047.0,
#                             "name": "Taxes"
#                         },
#                         {
#                             "total": 87109392.0,
#                             "name": "General Expenses"
#                         },
#                         {
#                             "total": 196466429.0,
#                             "name": "Debt Service"
#                         },
#                         {
#                             "total": 3198260.0,
#                             "name": "Office of Superintendent"
#                         },
#                         {
#                             "total": 15920063.0,
#                             "name": "Financial Services - CIP"
#                         },
#                         {
#                             "total": 287056885.0,
#                             "name": "Long-Term Purchased Power"
#                         },
#                         {
#                             "total": 55573481.0,
#                             "name": "Short-Term Purchased Power"
#                         },
#                         {
#                             "total": 63417769.0,
#                             "name": "Power Supply & Environmental Affairs - CIP"
#                         },
#                         {
#                             "total": 57204028.0,
#                             "name": "Customer Focused - CIP"
#                         },
#                         {
#                             "total": 51451102.0,
#                             "name": "Power Supply O&M"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "McCaw Hall Capital Reserve",
#             "children": [
#                 {
#                     "name": "Seattle Center",
#                     "children": [
#                         {
#                             "total": 500000.0,
#                             "name": "McCaw Hall Maintenance Fund (34070-CIP)"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Cumulative Reserve Subfund - Unrestricted Subaccount (00164)",
#             "children": [
#                 {
#                     "name": "Cumulative Reserve Subfund",
#                     "children": [
#                         {
#                             "total": 2500000.0,
#                             "name": "MOHAI Replacement Facilities"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 24781.0,
#                             "name": "Garden of Remembrance (00164-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Department of Planning and Development",
#                     "children": [
#                         {
#                             "total": 75678.0,
#                             "name": "Tenant Relocation Assistance Program - CRS-UR"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Department of Parks and Recreation",
#                     "children": [
#                         {
#                             "total": 840000.0,
#                             "name": "Building Component Renovations (00164-CIP)"
#                         },
#                         {
#                             "total": 305000.0,
#                             "name": "Ballfields/ Athletic Courts/ Play Areas (00164-CIP)"
#                         },
#                         {
#                             "total": 60000.0,
#                             "name": "Docks/ Piers/ Floats/ Seawalls/ Shorelines (00164- CIP)"
#                         },
#                         {
#                             "total": 101000.0,
#                             "name": "Forest Restoration (00164-CIP)"
#                         },
#                         {
#                             "total": 1611000.0,
#                             "name": "Debt Service and Contract Obligation (00164-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Center",
#                     "children": [
#                         {
#                             "total": 1317000.0,
#                             "name": "Monorail Improvements (00164-CIP)"
#                         },
#                         {
#                             "total": 30000.0,
#                             "name": "Campuswide Improvements and Repairs (00164-CIP)"
#                         },
#                         {
#                             "total": 90000.0,
#                             "name": "Public Gathering Space Improvements (00164-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Department of Transportation",
#                     "children": [
#                         {
#                             "total": 3004500.0,
#                             "name": "CRS-U Support to Transportation"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Office of Housing (16600)",
#             "children": [
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 4900613.0,
#                             "name": "Office of Housing Operating Fund 16600"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Transit Benefit Subfund (00410)",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 5400000.0,
#                             "name": "Transit Benefit"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Municipal Arts Fund (62600)",
#             "children": [
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 2513672.0,
#                             "name": "Municipal Arts Fund"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Health Care Subfund (00627)",
#             "children": [
#                 {
#                     "name": "Personnel Department",
#                     "children": [
#                         {
#                             "total": 175209976.0,
#                             "name": "Health Care"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Municipal Jail Subfund",
#             "children": [
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 1000000.0,
#                             "name": "Municipal Jail Bond Proceeds"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "UTGO Bond Interest and Redemption Fund",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 14799344.0,
#                             "name": "UTGO Debt Service"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "2014 Multipurpose LTGO Bond Fund",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 7038000.0,
#                             "name": "Information Technology (35800-CIP)"
#                         },
#                         {
#                             "total": 8649947.0,
#                             "name": "Neighborhood Fire Stations (35800-CIP)"
#                         },
#                         {
#                             "total": 11400000.0,
#                             "name": "Public Safety Facilities - Police (35800-CIP)"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Transportation Operating Fund (10310)",
#             "children": [
#                 {
#                     "name": "Seattle Department of Transportation",
#                     "children": [
#                         {
#                             "total": 21191999.0,
#                             "name": "Mobility-Capital"
#                         },
#                         {
#                             "total": 13623961.0,
#                             "name": "ROW Management"
#                         },
#                         {
#                             "total": 1233027.0,
#                             "name": "Department Management"
#                         },
#                         {
#                             "total": 4757205.0,
#                             "name": "Urban Forestry"
#                         },
#                         {
#                             "total": 34434728.0,
#                             "name": "General Expense"
#                         },
#                         {
#                             "total": 50913999.0,
#                             "name": "Major Maintenance/ Replacement"
#                         },
#                         {
#                             "total": 195968519.0,
#                             "name": "Major Projects"
#                         },
#                         {
#                             "total": 7718831.0,
#                             "name": "Bridges & Structures"
#                         },
#                         {
#                             "total": 2155438.0,
#                             "name": "Engineering Services"
#                         },
#                         {
#                             "total": 36371845.0,
#                             "name": "Mobility-Operations"
#                         },
#                         {
#                             "total": 23611175.0,
#                             "name": "Street Maintenance"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "General Subfund",
#             "children": [
#                 {
#                     "name": "Office of City Auditor",
#                     "children": [
#                         {
#                             "total": 1461132.0,
#                             "name": "Office of City Auditor"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Finance General",
#                     "children": [
#                         {
#                             "total": 64354345.0,
#                             "name": "Appropriation to General Fund Subfunds and Special Funds"
#                         },
#                         {
#                             "total": 36256696.0,
#                             "name": "Reserves"
#                         },
#                         {
#                             "total": 305641502.0,
#                             "name": "Support to Operating Funds"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Personnel Department",
#                     "children": [
#                         {
#                             "total": 2929443.0,
#                             "name": "Employee Health Services"
#                         },
#                         {
#                             "total": 2855226.0,
#                             "name": "Citywide Personnel Services"
#                         },
#                         {
#                             "total": 2890152.0,
#                             "name": "Employment and Training"
#                         },
#                         {
#                             "total": 3496441.0,
#                             "name": "City/ Union Relations and Class/ Comp Services"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 4206264.0,
#                             "name": "City Budget Office"
#                         },
#                         {
#                             "total": 6533471.0,
#                             "name": "Indigent Defense Services"
#                         },
#                         {
#                             "total": 2885852.0,
#                             "name": "Civil Rights"
#                         },
#                         {
#                             "total": 6230049.0,
#                             "name": "Office of Economic Development"
#                         },
#                         {
#                             "total": 2092173.0,
#                             "name": "Office of Sustainability and Environment"
#                         },
#                         {
#                             "total": 16702137.0,
#                             "name": "Jail Services"
#                         },
#                         {
#                             "total": 2089084.0,
#                             "name": "Intergovernmental Relations"
#                         },
#                         {
#                             "total": 3758088.0,
#                             "name": "Office of the Mayor"
#                         },
#                         {
#                             "total": 367588.0,
#                             "name": "Office of Immigrant and Refugee Affairs"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Police Department",
#                     "children": [
#                         {
#                             "total": 3628345.0,
#                             "name": "Chief of Police"
#                         },
#                         {
#                             "total": 6333699.0,
#                             "name": "Special Victims"
#                         },
#                         {
#                             "total": 1971424.0,
#                             "name": "Office of Professional Accountability"
#                         },
#                         {
#                             "total": 26322311.0,
#                             "name": "Deputy Chief of Staff"
#                         },
#                         {
#                             "total": 2332794.0,
#                             "name": "Deputy Chief Operations"
#                         },
#                         {
#                             "total": 8134776.0,
#                             "name": "Criminal Investigations Administration"
#                         },
#                         {
#                             "total": 39294528.0,
#                             "name": "Field Support Administration"
#                         },
#                         {
#                             "total": 17035206.0,
#                             "name": "South Precinct Patrol"
#                         },
#                         {
#                             "total": 4749243.0,
#                             "name": "Narcotics Investigations"
#                         },
#                         {
#                             "total": 7465891.0,
#                             "name": "Violent Crimes Investigations"
#                         },
#                         {
#                             "total": 45565654.0,
#                             "name": "Special Operations"
#                         },
#                         {
#                             "total": 31389723.0,
#                             "name": "North Precinct Patrol"
#                         },
#                         {
#                             "total": 23270580.0,
#                             "name": "East Precinct"
#                         },
#                         {
#                             "total": 1315411.0,
#                             "name": "Patrol Operations Administration"
#                         },
#                         {
#                             "total": 15414679.0,
#                             "name": "Southwest Precinct Patrol"
#                         },
#                         {
#                             "total": 4338182.0,
#                             "name": "Special Investigations"
#                         },
#                         {
#                             "total": 29024085.0,
#                             "name": "West Precinct Patrol"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Office of Hearing Examiner",
#                     "children": [
#                         {
#                             "total": 656328.0,
#                             "name": "Office of Hearing Examiner"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Civil Service Commissions",
#                     "children": [
#                         {
#                             "total": 385887.0,
#                             "name": "Civil Service Commissions"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Law Department",
#                     "children": [
#                         {
#                             "total": 11733147.0,
#                             "name": "Civil"
#                         },
#                         {
#                             "total": 2012668.0,
#                             "name": "Administration"
#                         },
#                         {
#                             "total": 6736333.0,
#                             "name": "Criminal"
#                         },
#                         {
#                             "total": 543410.0,
#                             "name": "Precinct Liaison Attorneys"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Fire Department",
#                     "children": [
#                         {
#                             "total": 146793970.0,
#                             "name": "Operations"
#                         },
#                         {
#                             "total": 411686.0,
#                             "name": "Grants & Reimbursables"
#                         },
#                         {
#                             "total": 7606981.0,
#                             "name": "Administration"
#                         },
#                         {
#                             "total": 11230855.0,
#                             "name": "Resource Management"
#                         },
#                         {
#                             "total": 7419132.0,
#                             "name": "Fire Prevention"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Municipal Court",
#                     "children": [
#                         {
#                             "total": 16517907.0,
#                             "name": "Court Operations"
#                         },
#                         {
#                             "total": 5492767.0,
#                             "name": "Court Compliance"
#                         },
#                         {
#                             "total": 6278790.0,
#                             "name": "Court Administration"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Legislative Department",
#                     "children": [
#                         {
#                             "total": 12558022.0,
#                             "name": "Legislative Department"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Department of Neighborhoods",
#                     "children": [
#                         {
#                             "total": 1426675.0,
#                             "name": "Internal Operations"
#                         },
#                         {
#                             "total": 485705.0,
#                             "name": "Director's Office"
#                         },
#                         {
#                             "total": 3458080.0,
#                             "name": "Community Building"
#                         },
#                         {
#                             "total": 5631045.0,
#                             "name": "Youth Violence Prevention"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Ethics and Elections Commission",
#                     "children": [
#                         {
#                             "total": 782800.0,
#                             "name": "Ethics and Elections"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Beach Maintenance Trust Fund",
#             "children": [
#                 {
#                     "name": "Department of Parks and Recreation",
#                     "children": [
#                         {
#                             "total": 25000.0,
#                             "name": "Docks/ Piers/ Floats/ Seawalls/ Shorelines (61500- CIP)"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Cumulative Reserve Subfund - REET II Subaccount (00161)",
#             "children": [
#                 {
#                     "name": "Department of Parks and Recreation",
#                     "children": [
#                         {
#                             "total": 1356000.0,
#                             "name": "Ballfields/ Athletic Courts/ Play Areas (00161-CIP)"
#                         },
#                         {
#                             "total": 475000.0,
#                             "name": "Parks Infrastructure (00161-CIP)"
#                         },
#                         {
#                             "total": 955000.0,
#                             "name": "Citywide and Neighborhood Projects (00161-CIP)"
#                         },
#                         {
#                             "total": 571000.0,
#                             "name": "Forest Restoration (00161-CIP)"
#                         },
#                         {
#                             "total": 1122000.0,
#                             "name": "Docks/ Piers/ Floats/ Seawalls/ Shorelines (00161- CIP)"
#                         },
#                         {
#                             "total": 1608000.0,
#                             "name": "Building Component Renovations (00161-CIP)"
#                         },
#                         {
#                             "total": 2018000.0,
#                             "name": "Debt Service and Contract Obligation (00161-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Seattle Department of Transportation",
#                     "children": [
#                         {
#                             "total": 9596000.0,
#                             "name": "CRS REET II Support to Transportation"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Cable Television Franchise Subfund (00160)",
#             "children": [
#                 {
#                     "name": "Department of Information Technology",
#                     "children": [
#                         {
#                             "total": 8669197.0,
#                             "name": "Cable Fee Support to Information Technology Fund"
#                         },
#                         {
#                             "total": 190000.0,
#                             "name": "Cable Fee Support to Library Fund"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "2012 Library Levy Fund (18100)",
#             "children": [
#                 {
#                     "name": "The Seattle Public Library",
#                     "children": [
#                         {
#                             "total": 3056000.0,
#                             "name": "Library Major Maintenance (18100-CIP)"
#                         },
#                         {
#                             "total": 12658704.0,
#                             "name": "Library Levy Operating Transfer"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Bond Interest and Redemption",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 1521014.0,
#                             "name": "Bond Interest and Redemption"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Community Development Block Grant Fund",
#             "children": [
#                 {
#                     "name": "Department of Parks and Recreation",
#                     "children": [
#                         {
#                             "total": 808000.0,
#                             "name": "Parks Infrastructure (17810-CIP)"
#                         },
#                         {
#                             "total": 732000.0,
#                             "name": "Building Component Renovations (17810-CIP)"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 1208675.0,
#                             "name": "CDBG - Office of Economic Development"
#                         },
#                         {
#                             "total": 1959680.0,
#                             "name": "CDBG - Office of Housing"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Human Services Department",
#                     "children": [
#                         {
#                             "total": 5291088.0,
#                             "name": "CDBG - Human Services Department"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Group Term Life Insurance Subfund (00628)",
#             "children": [
#                 {
#                     "name": "Personnel Department",
#                     "children": [
#                         {
#                             "total": 6234566.0,
#                             "name": "Group Term Life"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Solid Waste Fund",
#             "children": [
#                 {
#                     "name": "Seattle Public Utilities",
#                     "children": [
#                         {
#                             "total": 32077233.0,
#                             "name": "New Facilities"
#                         },
#                         {
#                             "total": 5022716.0,
#                             "name": "Administration"
#                         },
#                         {
#                             "total": 13048606.0,
#                             "name": "Customer Service"
#                         },
#                         {
#                             "total": 142950399.0,
#                             "name": "General Expense"
#                         },
#                         {
#                             "total": 2356531.0,
#                             "name": "Shared Cost Projects"
#                         },
#                         {
#                             "total": 16985077.0,
#                             "name": "Other Operating"
#                         },
#                         {
#                             "total": 45000.0,
#                             "name": "Rehabilitation and Heavy Equipment"
#                         },
#                         {
#                             "total": 4891677.0,
#                             "name": "Technology"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Arts Account (00140)",
#             "children": [
#                 {
#                     "name": "Executive",
#                     "children": [
#                         {
#                             "total": 4730087.0,
#                             "name": "Arts Account"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Employees' Retirement System Fund",
#             "children": [
#                 {
#                     "name": "Employees' Retirement System",
#                     "children": [
#                         {
#                             "total": 14133642.0,
#                             "name": "Personnel, Maintenance, and Operations"
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Finance and Administrative Services Fund (50300)",
#             "children": [
#                 {
#                     "name": "Department of Finance & Administrative Services",
#                     "children": [
#                         {
#                             "total": 222685.0,
#                             "name": "Judgment and Claims"
#                         },
#                         {
#                             "total": 4516938.0,
#                             "name": "Budget and Central Services"
#                         },
#                         {
#                             "total": 47667135.0,
#                             "name": "Fleet Services"
#                         },
#                         {
#                             "total": 2853183.0,
#                             "name": "Office of Constituent Services"
#                         },
#                         {
#                             "total": 65267359.0,
#                             "name": "Facility Services"
#                         },
#                         {
#                             "total": 3877135.0,
#                             "name": "City Purchasing and Contracting Services"
#                         },
#                         {
#                             "total": 3457271.0,
#                             "name": "Revenue and Consumer Protection"
#                         },
#                         {
#                             "total": 12865644.0,
#                             "name": "Business Technology"
#                         },
#                         {
#                             "total": 14205210.0,
#                             "name": "Financial Services"
#                         },
#                         {
#                             "total": 3500000.0,
#                             "name": "General Government Facilities - General (50300-CIP)"
#                         },
#                         {
#                             "total": 3160031.0,
#                             "name": "Technical Services"
#                         },
#                         {
#                             "total": 3343961.0,
#                             "name": "Seattle Animal Shelter"
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# Now finish the remaining two years:

# %%
df = pd.read_csv('budget2013.csv')
groupby_groups = ['Fund','Department','BCL Name']
value_label = '2013 Expenditure Allowance'
tree_json = treeify_dataframe(df,groupby_groups,value_label)

with open('budget2013.json','w') as f:
    json.dump(tree_json,f)

# %%
df = pd.read_csv('budget2014.csv')
groupby_groups = ['Fund','Department','BCL Name']
value_label = '2014 Expenditure Allowance'
tree_json = treeify_dataframe(df,groupby_groups,value_label)

with open('budget2014.json','w') as f:
    json.dump(tree_json,f)

# %% [markdown]
# And we're done! Now we have hierarchical JSON files that we can load into D3 and use to create sunburst charts.
